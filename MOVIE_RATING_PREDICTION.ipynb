# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("IMDb Movies India.csv",encoding='ISO-8859-1')

# %%
data
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %%
data.isna().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
impute1=SimpleImputer(strategy='median')
impute2=SimpleImputer(strategy='mean')

# %%
data['Rating_mean'] = impute2.fit_transform(data[['Rating']])

# %%
data['Name']=data['Name'].str.replace("#","")

# %%
data['Name']
# Out:
# 0
# 1        Gadhvi (He thought he was Gandhi)
# 2                               Homecoming
# 3                                   Yaaram
# 4                        ...And Once Again
#                        ...
# 15504                  Zulm Ko Jala Doonga
# 15505                                Zulmi
# 15506                            Zulmi Raj
# 15507                        Zulmi Shikari
# 15508                         Zulm-O-Sitam
# Name: Name, Length: 15509, dtype: object

# %%
data['Year']
# Out:
# 0           NaN
# 1        (2019)
# 2        (2021)
# 3        (2019)
# 4        (2010)
#           ...
# 15504    (1988)
# 15505    (1999)
# 15506    (2005)
# 15507    (1988)
# 15508    (1998)
# Name: Year, Length: 15509, dtype: object

# %%
# Extract the year values using regular expressions
data['Year'] = data['Year'].str.extract(r'(\d{4})')

# Convert the 'Year' column to numeric if needed
data['Year'] = pd.to_numeric(data['Year'])

# %%
data['Year_median']=impute1.fit_transform(data[['Year']])

# %%
data['Year_median']=data['Year_median'].astype(int)

# %%
data
# Out:
#                                     Name    Year Duration            Genre  \
# 0                                            NaN      NaN            Drama
# 1      Gadhvi (He thought he was Gandhi)  2019.0  109 min            Drama
# 2                             Homecoming  2021.0   90 min   Drama, Musical
# 3                                 Yaaram  2019.0  110 min  Comedy, Romance
# 4                      ...And Once Again  2010.0  105 min            Drama
# ...                                  ...     ...      ...              ...
# 15504                Zulm Ko Jala Doonga  1988.0      NaN           Action
# 15505                              Zulmi  1999.0  129 min    Action, Drama
# 15506                          Zulmi Raj  2005.0      NaN           Action
# 15507                      Zulmi Shikari  1988.0      NaN           Action
# 15508                       Zulm-O-Sitam  1998.0  130 min    Action, Drama
#
# ...

# %%
data=data

# %%
data['Duration']
# Out:
# 0            NaN
# 1        109 min
# 2         90 min
# 3        110 min
# 4        105 min
#           ...
# 15504        NaN
# 15505    129 min
# 15506        NaN
# 15507        NaN
# 15508    130 min
# Name: Duration, Length: 15509, dtype: object

# %%
data['Duration']=data['Duration'].str.replace("min","")

# %%
data['Duration']=pd.to_numeric(data['Duration'])

# %%
data['Duration']=impute2.fit_transform(data[['Duration']])

# %%
data['Duration']=data['Duration'].astype(int)

# %%
data
# Out:
#                                     Name    Year  Duration            Genre  \
# 0                                            NaN       128            Drama
# 1      Gadhvi (He thought he was Gandhi)  2019.0       109            Drama
# 2                             Homecoming  2021.0        90   Drama, Musical
# 3                                 Yaaram  2019.0       110  Comedy, Romance
# 4                      ...And Once Again  2010.0       105            Drama
# ...                                  ...     ...       ...              ...
# 15504                Zulm Ko Jala Doonga  1988.0       128           Action
# 15505                              Zulmi  1999.0       129    Action, Drama
# 15506                          Zulmi Raj  2005.0       128           Action
# 15507                      Zulmi Shikari  1988.0       128           Action
# 15508                       Zulm-O-Sitam  1998.0       130    Action, Drama
#
# ...

# %%
data.isna().sum()
# Out:
# Name              0
# Year            528
# Duration          0
# Genre          1877
# Rating         7590
# Votes          7589
# Director        525
# Actor 1        1617
# Actor 2        2384
# Actor 3        3144
# Rating_mean       0
# Year_median       0
# dtype: int64

# %%
data[['Actor 1','Actor 2','Actor 3','Director','Genre']]=data[['Actor 1','Actor 2','Actor 3','Director','Genre']].fillna('Unamed')

# %%
data
# Out:
#                                     Name    Year  Duration            Genre  \
# 0                                            NaN       128            Drama
# 1      Gadhvi (He thought he was Gandhi)  2019.0       109            Drama
# 2                             Homecoming  2021.0        90   Drama, Musical
# 3                                 Yaaram  2019.0       110  Comedy, Romance
# 4                      ...And Once Again  2010.0       105            Drama
# ...                                  ...     ...       ...              ...
# 15504                Zulm Ko Jala Doonga  1988.0       128           Action
# 15505                              Zulmi  1999.0       129    Action, Drama
# 15506                          Zulmi Raj  2005.0       128           Action
# 15507                      Zulmi Shikari  1988.0       128           Action
# 15508                       Zulm-O-Sitam  1998.0       130    Action, Drama
#
# ...

# %%
data.isna().sum()
# Out:
# Name              0
# Year            528
# Duration          0
# Genre             0
# Rating         7590
# Votes          7589
# Director          0
# Actor 1           0
# Actor 2           0
# Actor 3           0
# Rating_mean       0
# Year_median       0
# dtype: int64

# %%
data['Rating']=impute1.fit_transform(data[['Rating']])

# %%
data
# Out:
#                                     Name    Year  Duration            Genre  \
# 0                                            NaN       128            Drama
# 1      Gadhvi (He thought he was Gandhi)  2019.0       109            Drama
# 2                             Homecoming  2021.0        90   Drama, Musical
# 3                                 Yaaram  2019.0       110  Comedy, Romance
# 4                      ...And Once Again  2010.0       105            Drama
# ...                                  ...     ...       ...              ...
# 15504                Zulm Ko Jala Doonga  1988.0       128           Action
# 15505                              Zulmi  1999.0       129    Action, Drama
# 15506                          Zulmi Raj  2005.0       128           Action
# 15507                      Zulmi Shikari  1988.0       128           Action
# 15508                       Zulm-O-Sitam  1998.0       130    Action, Drama
#
# ...

# %%
data.isna().sum()
# Out:
# Name              0
# Year            528
# Duration          0
# Genre             0
# Rating            0
# Votes          7589
# Director          0
# Actor 1           0
# Actor 2           0
# Actor 3           0
# Rating_mean       0
# Year_median       0
# dtype: int64

# %%
data=data.drop('Year',axis=1)

# %%
data
# Out:
#                                     Name  Duration            Genre  Rating  \
# 0                                              128            Drama     6.0
# 1      Gadhvi (He thought he was Gandhi)       109            Drama     7.0
# 2                             Homecoming        90   Drama, Musical     6.0
# 3                                 Yaaram       110  Comedy, Romance     4.4
# 4                      ...And Once Again       105            Drama     6.0
# ...                                  ...       ...              ...     ...
# 15504                Zulm Ko Jala Doonga       128           Action     4.6
# 15505                              Zulmi       129    Action, Drama     4.5
# 15506                          Zulmi Raj       128           Action     6.0
# 15507                      Zulmi Shikari       128           Action     6.0
# 15508                       Zulm-O-Sitam       130    Action, Drama     6.2
#
# ...

# %%
data
# Out:
#                                     Name  Duration            Genre  Rating  \
# 0                                              128            Drama     6.0
# 1      Gadhvi (He thought he was Gandhi)       109            Drama     7.0
# 2                             Homecoming        90   Drama, Musical     6.0
# 3                                 Yaaram       110  Comedy, Romance     4.4
# 4                      ...And Once Again       105            Drama     6.0
# ...                                  ...       ...              ...     ...
# 15504                Zulm Ko Jala Doonga       128           Action     4.6
# 15505                              Zulmi       129    Action, Drama     4.5
# 15506                          Zulmi Raj       128           Action     6.0
# 15507                      Zulmi Shikari       128           Action     6.0
# 15508                       Zulm-O-Sitam       130    Action, Drama     6.2
#
# ...

# %%
data.head(6)
# Out:
#                                 Name  Duration                   Genre  \
# 0                                          128                   Drama
# 1  Gadhvi (He thought he was Gandhi)       109                   Drama
# 2                         Homecoming        90          Drama, Musical
# 3                             Yaaram       110         Comedy, Romance
# 4                  ...And Once Again       105                   Drama
# 5               ...Aur Pyaar Ho Gaya       147  Comedy, Drama, Musical
#
#    Rating Votes            Director       Actor 1                 Actor 2  \
# 0     6.0   NaN       J.S. Randhawa      Manmauji                  Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal          Vivek Ghamande
# 2     6.0   NaN  Soumyajit Majumdar  Sayani Gupta       Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik              Ishita Raj
# 4     6.0   NaN        Amol Palekar  Rajat Kapoor      Rituparna Sengupta
# ...

# %%
data['Votes'] = data['Votes'].fillna(0)

# %%
data
# Out:
#                                     Name  Duration            Genre  Rating  \
# 0                                              128            Drama     6.0
# 1      Gadhvi (He thought he was Gandhi)       109            Drama     7.0
# 2                             Homecoming        90   Drama, Musical     6.0
# 3                                 Yaaram       110  Comedy, Romance     4.4
# 4                      ...And Once Again       105            Drama     6.0
# ...                                  ...       ...              ...     ...
# 15504                Zulm Ko Jala Doonga       128           Action     4.6
# 15505                              Zulmi       129    Action, Drama     4.5
# 15506                          Zulmi Raj       128           Action     6.0
# 15507                      Zulmi Shikari       128           Action     6.0
# 15508                       Zulm-O-Sitam       130    Action, Drama     6.2
#
# ...

# %%
data['Votes']=data['Votes'].str.replace(",","")

# %%
data['Votes']=data['Votes'].str.replace("$","")
data['Votes']=data['Votes'].str.replace("M","")
data['Votes']=data['Votes'].str.replace(".","")

# %%
data['Votes']=pd.to_numeric(data['Votes'])

# %%
data
# Out:
#                                     Name  Duration            Genre  Rating  \
# 0                                              128            Drama     6.0
# 1      Gadhvi (He thought he was Gandhi)       109            Drama     7.0
# 2                             Homecoming        90   Drama, Musical     6.0
# 3                                 Yaaram       110  Comedy, Romance     4.4
# 4                      ...And Once Again       105            Drama     6.0
# ...                                  ...       ...              ...     ...
# 15504                Zulm Ko Jala Doonga       128           Action     4.6
# 15505                              Zulmi       129    Action, Drama     4.5
# 15506                          Zulmi Raj       128           Action     6.0
# 15507                      Zulmi Shikari       128           Action     6.0
# 15508                       Zulm-O-Sitam       130    Action, Drama     6.2
#
# ...

# %%
data['Votes']=impute2.fit_transform(data[['Votes']])

# %%
data
# Out:
#                                     Name  Duration            Genre  Rating  \
# 0                                              128            Drama     6.0
# 1      Gadhvi (He thought he was Gandhi)       109            Drama     7.0
# 2                             Homecoming        90   Drama, Musical     6.0
# 3                                 Yaaram       110  Comedy, Romance     4.4
# 4                      ...And Once Again       105            Drama     6.0
# ...                                  ...       ...              ...     ...
# 15504                Zulm Ko Jala Doonga       128           Action     4.6
# 15505                              Zulmi       129    Action, Drama     4.5
# 15506                          Zulmi Raj       128           Action     6.0
# 15507                      Zulmi Shikari       128           Action     6.0
# 15508                       Zulm-O-Sitam       130    Action, Drama     6.2
#
# ...

# %%
data=data.drop(['Name','Director','Actor 1','Actor 2','Actor 3'],axis=1)

# %%
data
# Out:
#        Duration            Genre  Rating        Votes  Rating_mean  \
# 0           128            Drama     6.0  1938.340783     5.841621
# 1           109            Drama     7.0     8.000000     7.000000
# 2            90   Drama, Musical     6.0  1938.340783     5.841621
# 3           110  Comedy, Romance     4.4    35.000000     4.400000
# 4           105            Drama     6.0  1938.340783     5.841621
# ...         ...              ...     ...          ...          ...
# 15504       128           Action     4.6    11.000000     4.600000
# 15505       129    Action, Drama     4.5   655.000000     4.500000
# 15506       128           Action     6.0  1938.340783     5.841621
# 15507       128           Action     6.0  1938.340783     5.841621
# 15508       130    Action, Drama     6.2    20.000000     6.200000
#
#        Year_median
# 0             1991
# 1             2019
# 2             2021
# 3             2019
# 4             2010
# ...            ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(data[['Genre']])
# Out:
# OneHotEncoder()

# %%
genre_encoded = ohe.transform(data[['Genre']])

# %%
genre_encoded
# Out:
# <15509x486 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15509 stored elements in Compressed Sparse Row format>

# %%
data=data.drop('Genre',axis=1)

# %%
data
# Out:
#        Duration  Rating        Votes  Rating_mean  Year_median
# 0           128     6.0  1938.340783     5.841621         1991
# 1           109     7.0     8.000000     7.000000         2019
# 2            90     6.0  1938.340783     5.841621         2021
# 3           110     4.4    35.000000     4.400000         2019
# 4           105     6.0  1938.340783     5.841621         2010
# ...         ...     ...          ...          ...          ...
# 15504       128     4.6    11.000000     4.600000         1988
# 15505       129     4.5   655.000000     4.500000         1999
# 15506       128     6.0  1938.340783     5.841621         2005
# 15507       128     6.0  1938.340783     5.841621         1988
# 15508       130     6.2    20.000000     6.200000         1998
#
# [15509 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(data.drop('Rating_mean',axis=1),data['Rating_mean'],test_size=0.3)

# %%
clf1=LinearRegression()

# %%
clf1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=clf1.predict(X_test)

# %%
y_pred
# Out:
# array([5.90637494, 5.92204644, 5.88128948, ..., 5.92583778, 5.83901581,
#        5.87655029])

# %%
score=clf1.score(X_train,y_train)

# %%
score
# Out:
# 0.9942418766184069
